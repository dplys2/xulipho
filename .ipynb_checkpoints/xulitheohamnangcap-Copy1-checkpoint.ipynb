# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import pandas as pd
from skimage import measure
from skimage.transform import rotate
from scipy.signal import savgol_filter
from tvxla import *

# %%
### Parameter
ghxd = 1600 # gioi han x duoi
ghxt = 3600 # gioi han x tren
dd = ghxt - ghxd + 1
dr = 5 # do rong chia 2
y = [651, 900, 1203, 1449, 1749, 1986]
goc = [180, 180, 177.75, 177.75, 177, 177]
ws = 49

filepath = 'D:\DataE\\20190715\\MO\\'
phan = 'mo'

# %%
kqd = np.zeros((dd, 6)).T
kqb = np.zeros((dd, 6)).T
kq = np.zeros((dd, 6)).T

for number in range(1,6,2):
    ad = np.zeros((dd, 6)).T
    ab = np.zeros((dd, 6)).T
    a = np.zeros((dd, 6)).T
    
    measurement = filepath + 'mau'  + str(number + 1) + '.jpg'
    base = filepath + 'mau'  + str(number) + '.jpg'
    print(base)
    for j in range(0,6,1):
        ab[j], ad[j], a[j] = xuliabs(base, measurement, y[j], goc[j], ghxd, ghxt, dr, ws, ptd = 0)
        print('Hoan thanh ' + str(int((j+1)/6*100)) + ' %' )
    
    print('\n')
    kqd = kqd + ad
    kqb = kqb + ab
    kq = kq + a

kqd = kqd/3.0
kqb = kqb/3.0
kq = kq/3.0
# Out:
# D:\DataE\20190715\MO\mau1.jpg
# Hoan thanh 16 %
# Hoan thanh 33 %
# Hoan thanh 50 %
# Hoan thanh 66 %
# Hoan thanh 83 %
# Hoan thanh 100 %
#
#
# D:\DataE\20190715\MO\mau3.jpg
# Hoan thanh 16 %
# Hoan thanh 33 %
# Hoan thanh 50 %
# Hoan thanh 66 %
# Hoan thanh 83 %
# Hoan thanh 100 %
#
#
# D:\DataE\20190715\MO\mau5.jpg
# Hoan thanh 16 %
# Hoan thanh 33 %
# Hoan thanh 50 %
# Hoan thanh 66 %
# Hoan thanh 83 %
# Hoan thanh 100 %

# %%
for i in range(0,6,1):
    plt.plot(kq[i], label='kenh' + str(i))
plt.legend(loc='upper right')
plt.show()

# %%
import pandas as pd

solieu = np.column_stack((kq[0], kq[1], kq[2], kq[3], kq[4], kq[5]))
filename = phan + '.csv'
df = pd.DataFrame(solieu)
df.to_csv(filepath + filename, index = False)

# %%
solieu = np.column_stack((kqd[0], kqd[1], kqd[2], kqd[3], kqd[4], kqd[5]))
df = pd.DataFrame(solieu)
df.to_csv(filepath + 'test.csv', index = False)

# %%
for i in range(0,6,1):
    plt.plot(kqd[i], label='kenh' + str(i))
plt.legend(loc='upper right')
plt.show()
