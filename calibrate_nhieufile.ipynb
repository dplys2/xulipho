# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import pandas as pd
from skimage import measure
from skimage.transform import rotate
from scipy.signal import savgol_filter
from tvxla import *

# %% [markdown]
# Calibrate bang den thuy ngan tu nhieu file

# %%
### Parameter
ghxd = 2300 # gioi han x duoi
ghxt = 4300 # gioi han x tren
dd = ghxt - ghxd + 1
dr = 5 # do rong chia 2
y = [819, 1031, 1311, 1519, 1799, 2020]
goc = [183.25, 182.75, 181.25, 181.0, 180.0, 179.0]
ws = 49

filepath = 'D:\DataE\\20190721\\CAL\\'
phan = 'ca'

# %%
kq = np.zeros((dd, 6)).T

for j in range(0,6,1):
    measurement = filepath + 'mau'  + str(j+1) + '.jpg'
    print(measurement)
    kq[j] = xulitt(measurement, y[j], goc[j], ghxd, ghxt, dr, ws, ptd = 0)
    print('Hoan thanh ' + str(int((j+1)/6*100)) + ' %' )
    print('\n')
# Out:
# D:\DataE\20190721\CAL\mau1.jpg
# Hoan thanh 16 %
#
#
# D:\DataE\20190721\CAL\mau2.jpg
# Hoan thanh 33 %
#
#
# D:\DataE\20190721\CAL\mau3.jpg
# Hoan thanh 50 %
#
#
# D:\DataE\20190721\CAL\mau4.jpg
# Hoan thanh 66 %
#
#
# D:\DataE\20190721\CAL\mau5.jpg
# Hoan thanh 83 %
#
#
# D:\DataE\20190721\CAL\mau6.jpg
# Hoan thanh 100 %

# %%
for i in range(0,6,1):
    plt.plot(kq[i], label='kenh' + str(i+1))
plt.legend(loc='upper right')
plt.show()

# %%
solieu = np.column_stack((kq[0], kq[1], kq[2], kq[3], kq[4], kq[5]))
filename = phan + '.csv'
df = pd.DataFrame(solieu)
df.to_csv(filepath + filename, index = False)
